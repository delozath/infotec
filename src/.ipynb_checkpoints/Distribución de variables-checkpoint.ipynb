# %% [markdown]
# # Distribución de variables

# %% [markdown]
# Suponga talla, edad

# %%
import numpy              as np
import matplotlib.pyplot as plt

# %%
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis  as LDA

# %%
mean = np.array( [25., 90.] )
cov  = np.array( [[50., 0], [0, 50.]] )

print 'M=%s'%mean
print '\nS=%s'%cov
# Out:
# M=[ 25.  90.]
#
# S=[[ 50.   0.]
#  [  0.  50.]]

# %%
X_C0 = np.random.multivariate_normal(mean, cov, 1000).T

# %%
plt.plot( X_C0[0],X_C0[1],'or',markersize=10)
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
mean = np.array( [45, 125] )
cov  = np.array( [[70, 0], [0, 70]] )
X_C1 = np.random.multivariate_normal(mean, cov, 1000).T

print 'M=%s'%mean
print '\nS=%s'%cov

plt.plot( X_C0[0], X_C0[1],'or',markersize=10)
plt.plot( X_C1[0], X_C1[1],'ob',markersize=10)
plt.axis('equal')
plt.grid(True)
plt.show()
# Out:
# M=[ 45 125]
#
# S=[[70  0]
#  [ 0 70]]

# %%
L_C0 = np.array( [-1]*X_C0.T.shape[0] )
L_C1 = np.array( [ 1]*X_C1.T.shape[0] )

# %%
X = np.hstack (  (np.array([ x0_c0, x1_c0]),np.array([ x0_c1, x1_c1]) )   )
Y = np.array( [-1]*x0_c0.shape[0] )
Y = np.concatenate(   (Y,np.array([1]*x0_c1.shape[0]) )  )
print Y
# Out:
# [-1 -1 -1 ...,  1  1  1]

# %%
lda = LDA()

TRAIN = 600

#X.T[:TRAIN].shape

model = lda.fit( X.T[:TRAIN].T, Y[:TRAIN])
#dir(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8f9e9766b0f0> in <module>()
#       5 #X.T[:TRAIN].shape
#       6
# ----> 7 model = lda.fit( X.T[:TRAIN].T, Y[:TRAIN])
#       8 #dir(model)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/discriminant_analysis.pyc in fit(self, X, y, store_covariance, tol)
#     440                           DeprecationWarning)
#     441             self.tol = tol
# --> 442         X, y = check_X_y(X, y, ensure_min_samples=2, estimator=self)
#     443         self.classes_ = unique_labels(y)
#     444
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     529         y = y.astype(np.float64)
#     530
# ...

# %% [markdown]
# $$\sum_{i=0}^n x^2$$
