# %% [markdown]
# # Data generator

# %%
import numpy  as np
import pandas as pd

from matplotlib import pyplot as plt

plt.style.use('bmh')

# %%
def data_XOR(M,S,N=400):
    X = np.random.multivariate_normal(M,S,N)
    Y = -2*( X.prod(axis=1) < 0 ) + 1
    
    return X.copy(),Y.copy()


N = 700
M = np.array( [0,0] )
S = np.array([[3,0],
              [0,3] ] )

X,Y = data_XOR(M,S,N)

plt.figure(figsize=(8,8))
plt.plot( X[Y==-1,0],X[Y==-1,1],'ro' )
plt.plot( X[Y== 1,0],X[Y== 1,1],'bo' )

# %%
# Out:
# array([ 0,  0, -2,  0, -2,  0, -2,  0, -2, -2,  0, -2, -2, -2,  0,  0, -2,
#        -2, -2, -2, -2, -2,  0, -2,  0, -2,  0,  0, -2, -2, -2, -2, -2, -2,
#         0,  0,  0, -2, -2,  0, -2,  0,  0, -2,  0, -2,  0, -2,  0,  0, -2,
#        -2,  0,  0, -2, -2,  0,  0,  0, -2, -2, -2,  0,  0, -2,  0,  0, -2,
#         0, -2,  0,  0,  0,  0,  0,  0, -2, -2, -2,  0,  0,  0, -2,  0,  0,
#        -2, -2,  0, -2, -2,  0,  0, -2,  0,  0, -2,  0,  0, -2,  0,  0,  0,
#         0, -2,  0,  0,  0, -2,  0, -2,  0,  0,  0, -2, -2, -2,  0,  0, -2,
#         0, -2,  0, -2, -2,  0, -2,  0, -2,  0, -2, -2, -2, -2,  0, -2, -2,
#         0,  0,  0,  0,  0, -2,  0,  0, -2, -2, -2, -2, -2, -2,  0, -2, -2,
#         0, -2, -2,  0,  0, -2,  0, -2, -2, -2, -2, -2,  0, -2, -2, -2,  0,
#         0, -2,  0, -2, -2, -2,  0,  0, -2, -2,  0, -2,  0,  0,  0, -2,  0,
#        -2,  0, -2,  0,  0,  0,  0, -2,  0,  0, -2, -2,  0, -2,  0,  0, -2,
#        -2,  0,  0,  0, -2,  0, -2, -2, -2,  0,  0,  0, -2, -2, -2,  0, -2,
#         0,  0, -2,  0,  0,  0, -2,  0, -2, -2, -2,  0,  0, -2,  0, -2,  0,
#         0,  0, -2,  0,  0,  0,  0,  0,  0,  0,  0, -2,  0, -2,  0, -2, -2,
#        -2, -2, -2,  0,  0,  0,  0, -2,  0,  0, -2, -2,  0,  0, -2,  0, -2,
#        -2, -2,  0,  0,  0,  0, -2, -2, -2, -2, -2,  0,  0,  0, -2, -2,  0,
#         0,  0,  0, -2,  0, -2,  0,  0,  0, -2,  0])
